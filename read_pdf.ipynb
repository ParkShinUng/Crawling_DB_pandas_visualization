# %%
# !pip install tabula-py

# %%
from tabula import read_pdf
df = read_pdf('data/damunhwa.pdf',pages='all')
print(type(df))
# Out:
# Got stderr: 11월 09, 2020 2:07:56 오후 org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# 경고: Using fallback font 'ArialMT' for '¸¼Àº°íµñ'
# 11월 09, 2020 2:07:57 오후 org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# 경고: Using fallback font 'ArialMT' for '¸¼Àº°íµñ'
# <class 'list'>

# %%
import pandas as pd

# %%
print(len(df))
# Out:
# 8

# %%
print(type(df[0]))
df[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      시도    학제        계 국제결혼 가정   외국인 가정 Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0   NaN   NaN      NaN     NaN     국내출생       중도입국        NaN        NaN
# 1   NaN   NaN        계       여        계          여          계          여
# 2    전국  초등학교  107,694  52,755   85,089     41,589      5,073      2,542
# 3    전국   중학교   26,773  13,504   19,532      9,833      2,459      1,295
# 4    전국  고등학교   12,478   6,428    9,049      4,650      1,415        727
# 5    전국   일반고    7,052   3,924    5,211      2,893        733        415
# 6    전국   특목고      676     251      537        175         82         41
# 7    전국  특성화고    4,250   2,035    2,917      1,407        546        249
# 8    전국   자율고      500     218      384        175         54         22
# 9    전국  각종학교      433     170      104         34        204         81
# 10   전국     계  147,378  72,857  113,774     56,106      9,151      4,645
# ...

# %%
df[1]
# Out:
#      시도    학제       계 국제결혼 가정  외국인 가정 Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0   NaN   NaN     NaN     NaN    국내출생       중도입국        NaN        NaN
# 1   NaN   NaN       계       여       계          여          계          여
# 2    서울   특목고      72      37      51         20          6          6
# 3    서울  특성화고     776     443     471        283        135         73
# 4    서울   자율고     146      59      83         33         28         11
# 5    서울  각종학교     180      74      31         11         51         23
# 6    서울     계  18,301   9,129  10,928      5,483      1,728        853
# 7    부산  초등학교   4,770   2,368   4,281      2,121        248        130
# 8    부산   중학교   1,003     538     808        438        124         70
# 9    부산  고등학교     478     233     337        173         91         39
# 10   부산   일반고     173     102     134         81         26         16
# 11   부산   특목고      47      11      30          6         11          1
# ...

# %%
print(df[0].shape)
#df[0].head()
data1_df = df[0]
print(data1_df.shape)
# Out:
# (15, 10)
# (15, 10)

# %%
data1_df.head()
# Out:
#     시도    학제        계 국제결혼 가정  외국인 가정 Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0  NaN   NaN      NaN     NaN    국내출생       중도입국        NaN        NaN
# 1  NaN   NaN        계       여       계          여          계          여
# 2   전국  초등학교  107,694  52,755  85,089     41,589      5,073      2,542
# 3   전국   중학교   26,773  13,504  19,532      9,833      2,459      1,295
# 4   전국  고등학교   12,478   6,428   9,049      4,650      1,415        727
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1          계          여
# 2     17,532      8,624
# 3      4,782      2,376
# 4      2,014      1,051

# %%
#index가 0,1 인 행을 삭제함, inplace=True설정해야만 원본데이터가 수정됨
data1_df.drop(index=[0,1],inplace=True)

# %%
#index를 재조정함, 인덱스가 컬럼으로 바뀔때 drop=True 로 설정하면 컬럼이 삭제됨
data1_df.reset_index(drop=True,inplace=True)

# %%
data1_df.head()
# Out:
#    시도    학제        계 국제결혼 가정  외국인 가정 Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0  전국  초등학교  107,694  52,755  85,089     41,589      5,073      2,542
# 1  전국   중학교   26,773  13,504  19,532      9,833      2,459      1,295
# 2  전국  고등학교   12,478   6,428   9,049      4,650      1,415        727
# 3  전국   일반고    7,052   3,924   5,211      2,893        733        415
# 4  전국   특목고      676     251     537        175         82         41
#
#   Unnamed: 3 Unnamed: 4
# 0     17,532      8,624
# 1      4,782      2,376
# 2      2,014      1,051
# 3      1,108        616
# 4         57         35
